# %%
# !git clone https://github.com/sinaziaee/surface-crack-detection.git
# Out:
# Cloning into 'surface-crack-detection'...
# remote: Enumerating objects: 977, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 977 (delta 4), reused 0 (delta 0), pack-reused 960
# Receiving objects: 100% (977/977), 227.65 MiB | 17.61 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Updating files: 100% (989/989), done.

# %%
# !mkdir /content/surface-crack-detection/dataset/Dataset

# %%
# !cp -r /content/drive/MyDrive/Dataset/train /content/surface-crack-detection/dataset/Dataset

# %%
import cv2
from google.colab.patches import cv2_imshow

data = cv2.imread('/content/surface-crack-detection/dataset/Dataset/train/image/1644359422.png', 0)

cv2_imshow(data)
# cv2.imwrite('/content/test3.png', data)
# print(data.shape)
# Out:
# <PIL.Image.Image image mode=L size=1516x1516 at 0x7FD9E0DD2A90>

# %%
# !cp /content/surface-crack-detection/src/model/unet_Dataset_checkpoint.hdf5 /content/drive/MyDrive/Dataset

# %%
# %cd /content/surface-crack-detection/src
# Out:
# /content/surface-crack-detection/src

# %%
# !python main.py --train
# Out:
# ##################
# Dataset: Dataset
# DIP:	 Dataset
# Arch:	 unet
# ##################
#
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/surface-crack-detection/src/util/data.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   image = np.array([cv2.imread(item, 0) for item in image_list])
# ...

# %%
# !cp -r /content/surface-crack-detection/dataset/Dataset/train/image /content/surface-crack-detection/dataset/Dataset/test

# %%
# !python main.py --test
# Out:
# ##################
# Dataset: Dataset
# DIP:	 Dataset
# Arch:	 unet
# ##################
#
# in not nn
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Loaded: ./model/unet_Dataset_checkpoint.hdf5
#
# loading
# <class 'generator'>
# /content/surface-crack-detection/src/nn/nn.py:146: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   results = nn.model.predict_generator(generator, len(images), verbose=1)
# fuckkkkkkkkkk
# Traceback (most recent call last):
#   File "main.py", line 43, in <module>
#     main()
#   File "main.py", line 38, in main
#     nn.test()
#   File "/content/surface-crack-detection/src/nn/nn.py", line 146, in test
#     results = nn.model.predict_generator(generator, len(images), verbose=1)
# ...
